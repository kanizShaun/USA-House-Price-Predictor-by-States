# %%
import pandas as pd
df = pd.read_csv(r'realtor-data.csv')
df
# Out:
#           status      price  bed  bath  acre_lot  \
# 0       for_sale    20000.0  1.0   1.0       NaN
# 1       for_sale    20000.0  1.0   1.0       NaN
# 2       for_sale    20000.0  1.0   1.0       NaN
# 3       for_sale    20000.0  1.0   1.0       NaN
# 4       for_sale    20000.0  1.0   1.0       NaN
# ...          ...        ...  ...   ...       ...
# 813154  for_sale  1209000.0  3.0   3.0      0.05
# 813155  for_sale   315000.0  NaN   1.0       NaN
# 813156  for_sale   699000.0  1.0   1.0       NaN
# 813157  for_sale  1600000.0  2.0   2.0       NaN
# 813158  for_sale   699000.0  4.0   2.0      0.04
#
#                                             full_address  \
# 0           35 Main St Trlr A5, South Windsor, CT, 06074
# 1           35 Main St Trlr A5, South Windsor, CT, 06074
# 2           35 Main St Trlr A5, South Windsor, CT, 06074
# 3           35 Main St Trlr A5, South Windsor, CT, 06074
# 4           35 Main St Trlr A5, South Windsor, CT, 06074
# ...

# %%
df.columns
# Out:
# Index(['status', 'price', 'bed', 'bath', 'acre_lot', 'full_address', 'street',
#        'city', 'state', 'house_size'],
#       dtype='object')

# %%
print(df['city'].unique())
# Out:
# ['South Windsor' 'Chester' 'Provincetown' ... 'Inwood' 'Nyc' 'Out Nj']

# %%
import pickle
import pandas as pd
df.to_pickle('C:Users/ntc/Downloads/MVPR/realtor-data.csv')    #to save the dataframe, df to 123.pkl
df1 = pd.read_pickle('C:Users/ntc/Downloads/MVPR/realtor-data.csv')
df1 #to load 123.pkl back to the dataframe df
# Out:
#   Input In [1]
#     df.to_pickle('C:\Users\ntc\Downloads/df.pkl')    #to save the dataframe, df to 123.pkl
#                                                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
